# %% [markdown]
# ### EXERCISE: APPLY BOTH APRIORI AND ECLAT ON GROCERIES_DATASET.CSV. THEN DO A COMPARATIVE ANALYSIS ON ECLAT, APRIORI, AND FP-GROWTH.

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules
import matplotlib.pyplot as plt
from graphviz import Digraph

df = pd.read_csv('Groceries_dataset.csv').sample(n=3000, random_state=42)
df
# Out:
#        Member_number        Date   itemDescription
# 22400           1449  03-10-2015    tropical fruit
# 38462           3010  13-06-2014  hygiene articles
# 36986           4789  09-04-2015  specialty cheese
# 2182            1884  11-12-2015       frankfurter
# 32319           1997  28-12-2015            pastry
# ...              ...         ...               ...
# 9633            2312  25-02-2014  other vegetables
# 10657           3294  26-02-2014            pastry
# 18959           1594  23-01-2015            yogurt
# 13793           2755  25-11-2014        whole milk
# 20723           2512  23-04-2015     bottled water
#
# [3000 rows x 3 columns]

# %%
# Converting the df to transactions
grouped = df.groupby(['Member_number', 'Date'])
transactions = grouped['itemDescription'].apply(list).values.tolist()

transactions
# Out:
# [['sausage'],
#  ['rolls/buns'],
#  ['dental care'],
#  ['dish cleaner'],
#  ['whole milk'],
#  ['margarine'],
#  ['chicken'],
#  ['yogurt', 'domestic eggs'],
#  ['herbs'],
#  ['bottled water'],
#  ['tropical fruit'],
#  ['frozen vegetables'],
#  ['whipped/sour cream'],
#  ['canned beer'],
#  ['butter milk'],
#  ['rolls/buns'],
#  ['root vegetables'],
#  ['curd'],
#  ['butter'],
#  ['curd'],
#  ['rolls/buns'],
#  ['butter'],
#  ['cream cheese '],
#  ['whole milk'],
#  ['snack products'],
#  ['cake bar'],
#  ['rolls/buns'],
#  ['butter', 'whipped/sour cream'],
#  ['whole milk'],
#  ['fruit/vegetable juice'],
#  ['specialty bar'],
#  ['meat'],
#  ['beverages', 'waffles'],
#  ['yogurt'],
#  ['shopping bags'],
#  ['yogurt'],
#  ['pork', 'other vegetables', 'detergent'],
#  ['pastry'],
#  ['waffles'],
#  ['sugar'],
#  ['soda'],
#  ['soda'],
#  ['other vegetables'],
#  ['whole milk'],
#  ['tropical fruit'],
#  ['whole milk'],
#  ['whole milk'],
#  ['whole milk'],
#  ['pork'],
#  ['soda'],
#  ['bottled beer'],
#  ['brown bread'],
#  ['semi-finished bread'],
#  ['shopping bags'],
#  ['canned fish'],
#  ['whole milk'],
#  ['pastry'],
#  ['rolls/buns'],
#  ['root vegetables'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['sliced cheese'],
#  ['meat'],
#  ['sausage'],
#  ['sausage'],
#  ['brown bread'],
#  ['curd', 'whipped/sour cream'],
#  ['napkins'],
#  ['cat food'],
#  ['soda'],
#  ['whole milk'],
#  ['whipped/sour cream'],
#  ['beverages'],
#  ['other vegetables', 'rolls/buns'],
#  ['misc. beverages'],
#  ['rolls/buns'],
#  ['citrus fruit'],
#  ['rolls/buns'],
#  ['grapes'],
#  ['pastry', 'oil'],
#  ['sugar'],
#  ['root vegetables'],
#  ['rolls/buns'],
#  ['chicken'],
#  ['meat'],
#  ['bottled beer'],
#  ['condensed milk'],
#  ['pickled vegetables'],
#  ['whole milk', 'pastry'],
#  ['frozen vegetables'],
#  ['dishes'],
#  ['canned vegetables'],
#  ['sausage'],
#  ['newspapers'],
#  ['rolls/buns'],
#  ['UHT-milk'],
#  ['soda'],
#  ['shopping bags'],
#  ['instant coffee'],
#  ['other vegetables'],
#  ['nut snack'],
#  ['napkins'],
#  ['whole milk'],
#  ['newspapers'],
#  ['misc. beverages'],
#  ['white bread'],
#  ['brown bread'],
#  ['bottled water'],
#  ['yogurt'],
#  ['berries'],
#  ['curd'],
#  ['shopping bags'],
#  ['soda'],
#  ['soda'],
#  ['ice cream'],
#  ['chicken'],
#  ['berries'],
#  ['beef'],
#  ['beef'],
#  ['berries'],
#  ['root vegetables'],
#  ['napkins'],
#  ['pip fruit'],
#  ['whipped/sour cream'],
#  ['hard cheese'],
#  ['whole milk'],
#  ['coffee'],
#  ['citrus fruit'],
#  ['white bread'],
#  ['rolls/buns', 'red/blush wine'],
#  ['root vegetables', 'brown bread'],
#  ['frankfurter'],
#  ['citrus fruit'],
#  ['shopping bags'],
#  ['tropical fruit'],
#  ['root vegetables'],
#  ['sparkling wine'],
#  ['white bread'],
#  ['butter'],
#  ['shopping bags'],
#  ['pip fruit'],
#  ['newspapers'],
#  ['whole milk'],
#  ['canned fish'],
#  ['bottled beer', 'chicken'],
#  ['yogurt', 'semi-finished bread', 'whole milk'],
#  ['frozen meals'],
#  ['fruit/vegetable juice'],
#  ['frankfurter'],
#  ['whole milk'],
#  ['tropical fruit'],
#  ['margarine'],
#  ['pip fruit'],
#  ['semi-finished bread'],
#  ['sauces'],
#  ['pastry'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['margarine'],
#  ['onions', 'condensed milk'],
#  ['specialty chocolate'],
#  ['curd'],
#  ['butter milk'],
#  ['whole milk'],
#  ['yogurt'],
#  ['bottled water'],
#  ['root vegetables'],
#  ['waffles', 'shopping bags'],
#  ['white bread'],
#  ['sausage'],
#  ['bottled beer', 'bottled water'],
#  ['brown bread'],
#  ['whole milk'],
#  ['sausage', 'bottled beer'],
#  ['domestic eggs'],
#  ['shopping bags'],
#  ['UHT-milk'],
#  ['soda'],
#  ['grapes'],
#  ['white bread'],
#  ['canned beer'],
#  ['candy'],
#  ['butter'],
#  ['packaged fruit/vegetables'],
#  ['coffee'],
#  ['chewing gum'],
#  ['processed cheese'],
#  ['herbs'],
#  ['hamburger meat'],
#  ['frozen meals'],
#  ['soda'],
#  ['white bread'],
#  ['bottled water'],
#  ['other vegetables'],
#  ['pork'],
#  ['sliced cheese'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['seasonal products'],
#  ['dessert'],
#  ['dessert'],
#  ['specialty chocolate'],
#  ['ice cream'],
#  ['whole milk'],
#  ['sausage'],
#  ['other vegetables'],
#  ['whole milk'],
#  ['UHT-milk'],
#  ['butter'],
#  ['domestic eggs'],
#  ['napkins', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['domestic eggs'],
#  ['specialty fat'],
#  ['long life bakery product'],
#  ['herbs'],
#  ['pastry'],
#  ['other vegetables'],
#  ['pot plants'],
#  ['sausage'],
#  ['tropical fruit'],
#  ['rolls/buns'],
#  ['brown bread'],
#  ['dessert'],
#  ['whipped/sour cream'],
#  ['yogurt'],
#  ['specialty bar'],
#  ['bottled beer'],
#  ['whole milk'],
#  ['whole milk'],
#  ['whipped/sour cream'],
#  ['sausage'],
#  ['bottled beer'],
#  ['yogurt'],
#  ['napkins'],
#  ['other vegetables'],
#  ['UHT-milk', 'whole milk'],
#  ['margarine'],
#  ['whole milk'],
#  ['whole milk'],
#  ['whole milk'],
#  ['bottled beer'],
#  ['soda'],
#  ['frozen vegetables'],
#  ['soda', 'oil'],
#  ['soda'],
#  ['domestic eggs'],
#  ['whole milk'],
#  ['chocolate'],
#  ['herbs'],
#  ['butter milk'],
#  ['other vegetables'],
#  ['whipped/sour cream'],
#  ['ham'],
#  ['tropical fruit'],
#  ['salt'],
#  ['whole milk'],
#  ['margarine'],
#  ['bottled beer'],
#  ['dish cleaner'],
#  ['bottled beer'],
#  ['bottled water'],
#  ['rolls/buns', 'candles'],
#  ['soft cheese'],
#  ['canned beer'],
#  ['tea'],
#  ['sugar'],
#  ['whole milk'],
#  ['chewing gum'],
#  ['bottled water'],
#  ['meat'],
#  ['popcorn'],
#  ['pork'],
#  ['rolls/buns'],
#  ['pip fruit'],
#  ['pip fruit'],
#  ['candy'],
#  ['tropical fruit'],
#  ['bottled beer'],
#  ['other vegetables'],
#  ['meat'],
#  ['long life bakery product'],
#  ['coffee'],
#  ['other vegetables'],
#  ['frankfurter'],
#  ['photo/film'],
#  ['chicken'],
#  ['male cosmetics'],
#  ['other vegetables'],
#  ['salty snack'],
#  ['condensed milk'],
#  ['other vegetables', 'waffles'],
#  ['soda'],
#  ['fruit/vegetable juice'],
#  ['processed cheese'],
#  ['pasta'],
#  ['citrus fruit'],
#  ['citrus fruit'],
#  ['sliced cheese'],
#  ['yogurt'],
#  ['white wine'],
#  ['napkins'],
#  ['chicken'],
#  ['yogurt'],
#  ['cream cheese '],
#  ['tropical fruit'],
#  ['citrus fruit'],
#  ['pickled vegetables'],
#  ['rolls/buns'],
#  ['liquor'],
#  ['tropical fruit'],
#  ['margarine'],
#  ['misc. beverages'],
#  ['chicken'],
#  ['specialty bar'],
#  ['specialty chocolate'],
#  ['waffles'],
#  ['grapes'],
#  ['yogurt'],
#  ['whipped/sour cream'],
#  ['meat', 'shopping bags'],
#  ['whole milk'],
#  ['ham'],
#  ['fruit/vegetable juice'],
#  ['whipped/sour cream'],
#  ['curd cheese'],
#  ['root vegetables'],
#  ['pork'],
#  ['sausage'],
#  ['detergent'],
#  ['rolls/buns'],
#  ['pip fruit'],
#  ['packaged fruit/vegetables', 'tidbits'],
#  ['soft cheese'],
#  ['soda'],
#  ['beef'],
#  ['other vegetables'],
#  ['cling film/bags'],
#  ['sausage'],
#  ['UHT-milk'],
#  ['packaged fruit/vegetables'],
#  ['whipped/sour cream'],
#  ['butter milk'],
#  ['long life bakery product'],
#  ['shopping bags'],
#  ['sausage'],
#  ['dishes'],
#  ['bottled water'],
#  ['fruit/vegetable juice'],
#  ['rolls/buns'],
#  ['liquor'],
#  ['specialty bar'],
#  ['domestic eggs'],
#  ['shopping bags'],
#  ['pasta'],
#  ['hamburger meat'],
#  ['waffles'],
#  ['pork'],
#  ['seasonal products'],
#  ['newspapers'],
#  ['brown bread'],
#  ['bottled beer'],
#  ['rolls/buns'],
#  ['frozen vegetables'],
#  ['pastry'],
#  ['citrus fruit'],
#  ['shopping bags'],
#  ['other vegetables'],
#  ['yogurt'],
#  ['yogurt'],
#  ['pickled vegetables'],
#  ['bottled beer'],
#  ['pastry'],
#  ['beef'],
#  ['soda'],
#  ['mustard'],
#  ['sliced cheese'],
#  ['tropical fruit'],
#  ['herbs'],
#  ['white bread'],
#  ['flour'],
#  ['sliced cheese'],
#  ['chewing gum'],
#  ['oil'],
#  ['whole milk'],
#  ['specialty cheese'],
#  ['candy'],
#  ['candy'],
#  ['misc. beverages'],
#  ['bottled beer', 'sausage'],
#  ['candy'],
#  ['frankfurter'],
#  ['flour'],
#  ['pastry'],
#  ['whole milk'],
#  ['packaged fruit/vegetables'],
#  ['other vegetables'],
#  ['pip fruit'],
#  ['sugar'],
#  ['sliced cheese'],
#  ['newspapers', 'frankfurter'],
#  ['onions'],
#  ['yogurt'],
#  ['pork'],
#  ['packaged fruit/vegetables'],
#  ['rolls/buns'],
#  ['sausage'],
#  ['yogurt'],
#  ['yogurt'],
#  ['nut snack'],
#  ['bottled beer'],
#  ['yogurt'],
#  ['sliced cheese'],
#  ['rolls/buns'],
#  ['tropical fruit'],
#  ['pip fruit'],
#  ['margarine'],
#  ['cream cheese '],
#  ['frozen vegetables'],
#  ['citrus fruit'],
#  ['hamburger meat'],
#  ['fruit/vegetable juice'],
#  ['pickled vegetables'],
#  ['other vegetables', 'sugar'],
#  ['ice cream'],
#  ['salt'],
#  ['bottled water'],
#  ['whole milk'],
#  ['coffee'],
#  ['sugar', 'dish cleaner'],
#  ['root vegetables'],
#  ['napkins', 'frozen dessert'],
#  ['waffles'],
#  ['photo/film'],
#  ['canned fish'],
#  ['napkins'],
#  ['red/blush wine'],
#  ['butter milk'],
#  ['pastry'],
#  ['cream cheese '],
#  ['pastry'],
#  ['domestic eggs'],
#  ['rolls/buns'],
#  ['whole milk'],
#  ['frankfurter'],
#  ['brown bread', 'yogurt'],
#  ['chicken'],
#  ['chocolate'],
#  ['whole milk'],
#  ['pastry'],
#  ['bottled water'],
#  ['salty snack'],
#  ['butter'],
#  ['sliced cheese'],
#  ['chewing gum'],
#  ['shopping bags'],
#  ['cat food'],
#  ['whole milk'],
#  ['frozen dessert'],
#  ['liquor (appetizer)'],
#  ['frankfurter'],
#  ['packaged fruit/vegetables'],
#  ['specialty chocolate'],
#  ['pip fruit'],
#  ['whole milk'],
#  ['beef'],
#  ['yogurt'],
#  ['dishes'],
#  ['other vegetables'],
#  ['other vegetables'],
#  ['cake bar'],
#  ['coffee', 'whole milk'],
#  ['root vegetables'],
#  ['coffee'],
#  ['UHT-milk'],
#  ['brown bread'],
#  ['other vegetables'],
#  ['cake bar'],
#  ['onions'],
#  ['waffles'],
#  ['pip fruit'],
#  ['dish cleaner'],
#  ['canned vegetables'],
#  ['shopping bags'],
#  ['other vegetables'],
#  ['whole milk'],
#  ['cream cheese '],
#  ['sauces'],
#  ['baking powder'],
#  ['bottled water'],
#  ['grapes'],
#  ['cat food'],
#  ['whole milk'],
#  ['cream cheese '],
#  ['bottled water'],
#  ['canned beer'],
#  ['newspapers'],
#  ['pip fruit'],
#  ['pastry'],
#  ['other vegetables'],
#  ['waffles'],
#  ['semi-finished bread'],
#  ['whole milk'],
#  ['sausage'],
#  ['canned beer'],
#  ['root vegetables'],
#  ['white bread'],
#  ['yogurt'],
#  ['whipped/sour cream'],
#  ['whole milk'],
#  ['whole milk'],
#  ['instant coffee'],
#  ['citrus fruit'],
#  ['ham'],
#  ['curd'],
#  ['brown bread'],
#  ['whipped/sour cream'],
#  ['pip fruit'],
#  ['cream cheese '],
#  ['margarine'],
#  ['onions'],
#  ['rolls/buns'],
#  ['beef'],
#  ['pip fruit'],
#  ['newspapers'],
#  ['fruit/vegetable juice'],
#  ['curd'],
#  ['pickled vegetables'],
#  ['other vegetables'],
#  ['UHT-milk'],
#  ['soda'],
#  ['white bread', 'frankfurter', 'hamburger meat'],
#  ['oil', 'bottled beer'],
#  ['shopping bags'],
#  ['shopping bags'],
#  ['mustard'],
#  ['bottled beer'],
#  ['coffee'],
#  ['butter'],
#  ['rolls/buns'],
#  ['dessert'],
#  ['whole milk'],
#  ['butter milk'],
#  ['other vegetables'],
#  ['semi-finished bread'],
#  ['soda'],
#  ['specialty bar', 'other vegetables'],
#  ['frankfurter'],
#  ['domestic eggs'],
#  ['cat food'],
#  ['yogurt'],
#  ['brown bread'],
#  ['sausage'],
#  ['beef'],
#  ['bottled water'],
#  ['rolls/buns', 'specialty bar'],
#  ['yogurt'],
#  ['other vegetables'],
#  ['whole milk'],
#  ['candles'],
#  ['whole milk'],
#  ['bottled water'],
#  ['newspapers'],
#  ['ice cream'],
#  ['sausage'],
#  ['chocolate marshmallow'],
#  ['whole milk'],
#  ['ham'],
#  ['mustard'],
#  ['napkins'],
#  ['candy'],
#  ['meat'],
#  ['whole milk'],
#  ['domestic eggs', 'butter milk'],
#  ['pickled vegetables'],
#  ['whole milk'],
#  ['tropical fruit'],
#  ['photo/film'],
#  ['soda'],
#  ['root vegetables'],
#  ['whole milk'],
#  ['whole milk'],
#  ['soda'],
#  ['root vegetables'],
#  ['hard cheese'],
#  ['frankfurter'],
#  ['tropical fruit'],
#  ['sugar'],
#  ['specialty chocolate'],
#  ['citrus fruit'],
#  ['long life bakery product'],
#  ['zwieback'],
#  ['tropical fruit'],
#  ['sugar'],
#  ['chicken'],
#  ['bottled beer', 'root vegetables'],
#  ['citrus fruit'],
#  ['sausage'],
#  ['mustard'],
#  ['soda'],
#  ['tropical fruit'],
#  ['cake bar'],
#  ['fruit/vegetable juice'],
#  ['frozen fish'],
#  ['hamburger meat'],
#  ['whole milk'],
#  ['pip fruit'],
#  ['butter milk'],
#  ['soda', 'root vegetables'],
#  ['rolls/buns'],
#  ['beef'],
#  ['seasonal products'],
#  ['seasonal products'],
#  ['pasta'],
#  ['UHT-milk'],
#  ['oil'],
#  ['brown bread'],
#  ['ice cream'],
#  ['pip fruit'],
#  ['brown bread'],
#  ['citrus fruit'],
#  ['baking powder'],
#  ['cake bar'],
#  ['chicken'],
#  ['onions'],
#  ['soda'],
#  ['whole milk'],
#  ['beverages'],
#  ['other vegetables'],
#  ['frankfurter', 'coffee'],
#  ['soda', 'artif. sweetener'],
#  ['rolls/buns'],
#  ['pork'],
#  ['curd'],
#  ['hygiene articles'],
#  ['honey'],
#  ['canned beer'],
#  ['specialty cheese'],
#  ['pip fruit'],
#  ['sugar', 'beef'],
#  ['brown bread'],
#  ['long life bakery product'],
#  ['zwieback'],
#  ['bottled water'],
#  ['shopping bags'],
#  ['sauces'],
#  ['sausage'],
#  ['rolls/buns'],
#  ['pastry', 'newspapers'],
#  ['rolls/buns'],
#  ['dessert'],
#  ['white wine'],
#  ['pip fruit'],
#  ['pastry'],
#  ['other vegetables'],
#  ['tropical fruit', 'oil'],
#  ['citrus fruit'],
#  ['newspapers'],
#  ['rolls/buns'],
#  ['candy'],
#  ['soda'],
#  ['tropical fruit'],
#  ['mayonnaise'],
#  ['beef'],
#  ['chewing gum'],
#  ['tropical fruit'],
#  ['other vegetables'],
#  ['whole milk'],
#  ['butter'],
#  ['whole milk'],
#  ['UHT-milk', 'UHT-milk'],
#  ['tropical fruit'],
#  ['pastry'],
#  ['bottled beer'],
#  ['ham'],
#  ['whole milk'],
#  ['tropical fruit'],
#  ['pasta', 'pork', 'tropical fruit'],
#  ['bottled beer'],
#  ['sausage'],
#  ['cereals'],
#  ['cream cheese '],
#  ['brown bread'],
#  ['other vegetables'],
#  ['soda'],
#  ['rolls/buns'],
#  ['beef'],
#  ['yogurt'],
#  ['detergent'],
#  ['brown bread'],
#  ['domestic eggs'],
#  ['salty snack'],
#  ['berries'],
#  ['pastry', 'ice cream'],
#  ['rolls/buns'],
#  ['whole milk'],
#  ['whole milk'],
#  ['pork'],
#  ['bottled beer', 'grapes'],
#  ['chicken'],
#  ['frozen fish'],
#  ['beef'],
#  ['waffles'],
#  ['soda'],
#  ['margarine', 'shopping bags'],
#  ['brown bread'],
#  ['domestic eggs'],
#  ['roll products '],
#  ['soda', 'rolls/buns'],
#  ['ham'],
#  ['pip fruit'],
#  ['pastry'],
#  ['chewing gum'],
#  ['misc. beverages', 'pastry'],
#  ['whole milk'],
#  ['waffles'],
#  ['shopping bags'],
#  ['tropical fruit'],
#  ['frozen dessert'],
#  ['specialty bar', 'whole milk'],
#  ['shopping bags'],
#  ['whipped/sour cream'],
#  ['bottled water'],
#  ['cake bar'],
#  ['tropical fruit', 'waffles'],
#  ['chocolate'],
#  ['chicken'],
#  ['yogurt'],
#  ['soft cheese'],
#  ['white wine'],
#  ['UHT-milk'],
#  ['spread cheese'],
#  ['roll products '],
#  ['canned beer'],
#  ['detergent'],
#  ['grapes'],
#  ['meat'],
#  ['other vegetables'],
#  ['butter', 'whole milk'],
#  ['whole milk'],
#  ['brandy'],
#  ['sweet spreads'],
#  ['frozen vegetables'],
#  ['rolls/buns'],
#  ['flour'],
#  ['newspapers'],
#  ['coffee', 'canned beer'],
#  ['citrus fruit'],
#  ['rolls/buns'],
#  ['brandy'],
#  ['frankfurter'],
#  ['newspapers'],
#  ['cream cheese '],
#  ['waffles', 'soda'],
#  ['whole milk'],
#  ['specialty chocolate'],
#  ['oil'],
#  ['specialty bar'],
#  ['herbs'],
#  ['hygiene articles'],
#  ['salty snack'],
#  ['beef'],
#  ['rum'],
#  ['citrus fruit'],
#  ['shopping bags'],
#  ['beverages'],
#  ['seasonal products'],
#  ['spices'],
#  ['butter'],
#  ['detergent'],
#  ['soda'],
#  ['brown bread'],
#  ['dog food'],
#  ['yogurt'],
#  ['root vegetables'],
#  ['grapes'],
#  ['canned fish'],
#  ['rum'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['soda'],
#  ['newspapers', 'dog food'],
#  ['misc. beverages'],
#  ['whole milk', 'frankfurter'],
#  ['yogurt'],
#  ['fruit/vegetable juice'],
#  ['frankfurter', 'baking powder'],
#  ['tropical fruit'],
#  ['whipped/sour cream'],
#  ['whole milk'],
#  ['frozen meals'],
#  ['other vegetables'],
#  ['soda'],
#  ['frozen meals'],
#  ['brandy'],
#  ['soda'],
#  ['rolls/buns'],
#  ['pip fruit'],
#  ['sparkling wine'],
#  ['beef'],
#  ['chocolate'],
#  ['cat food', 'other vegetables'],
#  ['pastry'],
#  ['soda'],
#  ['pip fruit'],
#  ['soda'],
#  ['sausage'],
#  ['curd', 'root vegetables'],
#  ['tropical fruit'],
#  ['onions'],
#  ['pork'],
#  ['organic products'],
#  ['bottled water'],
#  ['whole milk'],
#  ['newspapers'],
#  ['berries'],
#  ['waffles'],
#  ['whisky'],
#  ['butter'],
#  ['soda'],
#  ['chocolate'],
#  ['frozen vegetables'],
#  ['bottled water'],
#  ['domestic eggs'],
#  ['newspapers'],
#  ['sliced cheese'],
#  ['sugar'],
#  ['soda'],
#  ['whole milk'],
#  ['fruit/vegetable juice'],
#  ['pip fruit'],
#  ['citrus fruit'],
#  ['liquor'],
#  ['sauces'],
#  ['frozen fish'],
#  ['whipped/sour cream'],
#  ['chicken'],
#  ['female sanitary products'],
#  ['male cosmetics'],
#  ['margarine'],
#  ['ham'],
#  ['shopping bags'],
#  ['flour'],
#  ['whipped/sour cream'],
#  ['fruit/vegetable juice'],
#  ['pip fruit', 'hamburger meat'],
#  ['frankfurter'],
#  ['waffles'],
#  ['dessert'],
#  ['specialty bar'],
#  ['chocolate'],
#  ['citrus fruit'],
#  ['misc. beverages'],
#  ['cream'],
#  ['sugar'],
#  ['tropical fruit'],
#  ['sausage'],
#  ['whole milk'],
#  ['canned beer'],
#  ['red/blush wine'],
#  ['whole milk'],
#  ['brown bread'],
#  ['other vegetables'],
#  ['sausage'],
#  ['whole milk'],
#  ['flower soil/fertilizer'],
#  ['chocolate', 'root vegetables'],
#  ['berries'],
#  ['soda'],
#  ['tropical fruit'],
#  ['whole milk'],
#  ['pastry'],
#  ['meat'],
#  ['meat'],
#  ['candy', 'rolls/buns'],
#  ['brown bread'],
#  ['frozen meals'],
#  ['herbs'],
#  ['finished products'],
#  ['sliced cheese'],
#  ['whole milk'],
#  ['turkey'],
#  ['domestic eggs'],
#  ['rolls/buns'],
#  ['other vegetables'],
#  ['condensed milk'],
#  ['curd', 'bottled water'],
#  ['whole milk'],
#  ['packaged fruit/vegetables'],
#  ['soda'],
#  ['sausage'],
#  ['root vegetables'],
#  ['onions'],
#  ['tropical fruit'],
#  ['frankfurter'],
#  ['canned beer'],
#  ['soft cheese'],
#  ['whole milk'],
#  ['semi-finished bread'],
#  ['other vegetables', 'oil'],
#  ['berries'],
#  ['other vegetables'],
#  ['frankfurter'],
#  ['bottled water'],
#  ['rolls/buns'],
#  ['pork'],
#  ['pork'],
#  ['hygiene articles'],
#  ['curd'],
#  ['instant coffee'],
#  ['frozen meals'],
#  ['UHT-milk'],
#  ['chocolate'],
#  ['tropical fruit'],
#  ['specialty fat'],
#  ['grapes'],
#  ['pip fruit'],
#  ['shopping bags'],
#  ['rolls/buns'],
#  ['specialty bar'],
#  ['misc. beverages'],
#  ['napkins'],
#  ['other vegetables'],
#  ['white bread'],
#  ['grapes'],
#  ['dessert', 'sausage'],
#  ['other vegetables'],
#  ['pot plants'],
#  ['other vegetables'],
#  ['hamburger meat'],
#  ['beverages'],
#  ['bottled beer'],
#  ['newspapers'],
#  ['sausage'],
#  ['pip fruit'],
#  ['packaged fruit/vegetables'],
#  ['flour'],
#  ['whole milk', 'UHT-milk'],
#  ['whipped/sour cream'],
#  ['misc. beverages'],
#  ['hygiene articles'],
#  ['whole milk'],
#  ['other vegetables', 'shopping bags'],
#  ['rum'],
#  ['hygiene articles'],
#  ['soda'],
#  ['canned beer'],
#  ['bottled beer'],
#  ['chicken'],
#  ['sausage'],
#  ['whipped/sour cream'],
#  ['domestic eggs'],
#  ['whole milk'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['tropical fruit'],
#  ['specialty bar'],
#  ['bottled beer'],
#  ['beef'],
#  ['whole milk'],
#  ['UHT-milk', 'rolls/buns'],
#  ['candy', 'frankfurter'],
#  ['yogurt', 'pastry'],
#  ['cleaner'],
#  ['chocolate', 'whole milk'],
#  ['soda'],
#  ['bottled water', 'canned beer'],
#  ['pastry'],
#  ['long life bakery product'],
#  ['hamburger meat'],
#  ['sausage'],
#  ['yogurt'],
#  ['specialty chocolate'],
#  ['tropical fruit', 'chicken'],
#  ['tropical fruit'],
#  ['pork'],
#  ['chewing gum'],
#  ['hamburger meat'],
#  ['bottled water'],
#  ['canned fish'],
#  ['newspapers', 'shopping bags'],
#  ['napkins'],
#  ['white bread'],
#  ['root vegetables'],
#  ['butter'],
#  ['specialty chocolate'],
#  ['meat'],
#  ['spread cheese'],
#  ['yogurt'],
#  ['rolls/buns'],
#  ['soft cheese'],
#  ['berries'],
#  ['herbs'],
#  ['hard cheese'],
#  ['cat food'],
#  ['chicken'],
#  ['tropical fruit'],
#  ['long life bakery product'],
#  ['shopping bags'],
#  ['whipped/sour cream'],
#  ...]

# %%
data = pd.DataFrame(transactions)
data
# Out:
#                      0     1     2     3
# 0              sausage  None  None  None
# 1           rolls/buns  None  None  None
# 2          dental care  None  None  None
# 3         dish cleaner  None  None  None
# 4           whole milk  None  None  None
# ...                ...   ...   ...   ...
# 2775       salty snack  None  None  None
# 2776              soda  None  None  None
# 2777        white wine  None  None  None
# 2778         detergent  None  None  None
# 2779  other vegetables  None  None  None
#
# [2780 rows x 4 columns]

# %%
# Looking for itemSETS
# we do not want to have any individual products returned
min_n_products = 2

# we want to set min support to 7
# but we have to express it as a percentage
min_support = 700/len(transactions)

# we have no limit on the size of association rules
# so we set it to the longest transaction
max_length = max([len(x) for x in transactions])

# %%
print(max_length)
# Out:
# 4

# %%
from pyECLAT import ECLAT

# Creating an instance of eclat
my_eclat = ECLAT(data=data, verbose=True)

# Fitting the algorithm
rule_indices, rule_supports = my_eclat.fit(min_support=min_support,
                                           min_combination=min_n_products,
                                           max_combination=max_length)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 149/149 [00:00<00:00, 1746.28it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 149/149 [00:00<00:00, 16515.19it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 149/149 [00:00<00:00, 9124.31it/s]
# Combination 2 by 2
# 0it [00:00, ?it/s]
# Combination 3 by 3
# 0it [00:00, ?it/s]
# Combination 4 by 4
# 0it [00:00, ?it/s]

# %%
rule_indices
# Out:
# {}

# %%
print(rule_supports)
# Out:
# {}

# %%
# result via FP growth

# Transforming data using TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# Generating frequent itemsets using FP-Growth
frequent_itemsets = fpgrowth(df, min_support=0.005, use_colnames=True)
print("Frequent Itemsets:")
print(frequent_itemsets)

# Generating association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
print("\nAssociation Rules:")
print(rules)
# Out:
# Frequent Itemsets:
#      support                    itemsets
# 0   0.026619                   (sausage)
# 1   0.049281                (rolls/buns)
# 2   0.076259                (whole milk)
# 3   0.014388                 (margarine)
# 4   0.013309                   (chicken)
# ..       ...                         ...
# 56  0.009712                   (dessert)
# 57  0.007914  (long life bakery product)
# 58  0.011151                 (chocolate)
# 59  0.007914                       (ham)
# 60  0.006475          (hygiene articles)
#
# [61 rows x 2 columns]
#
# Association Rules:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
